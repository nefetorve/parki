# %% [markdown]
# <a href="https://colab.research.google.com/github/nefetorve/parki/blob/main/parki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np


data_raw = pd.read_excel(io="Trasy.xlsx",index_col=0)
copy_df = data_raw.copy()
data_trasy = data_raw.copy()
copy_df.head()
# Out:
#                                                             Dworzec Główny  ... Park Tysiąclecia
# Dworzec Główny                                                         NaN  ...              NaN
# Park Bieńkowicki                   Przesiadki (26 minut) + 4 minuty pieszo  ...              NaN
# Park generała Mariana Langiewicza                9 minut + 10 minut pieszo  ...              NaN
# Park Mikołaja Kopernika                            15 minut + 0 min pieszo  ...              NaN
# Park Świętej Edyty Stein                           19 minut + 3 min pieszo  ...              NaN
#
# [5 rows x 31 columns]

# %%
data_col_row = copy_df.iloc[:,:].values

# %%
col_size, row_size = data_col_row.shape

# %%
row_list = []
for j in range(col_size):
  row_list.append(data_col_row[:][j])

# %%
import re
#element = row_list[4][1]
#temp = re.findall(r'\d+', element)
#res = list(map(int, temp))
#res[-1]+res[-2]

# %%
for col in range(col_size):
  print(f"--------{col}---------")
  for row in range(row_size):
    #print(type(row_list[row][col]))
    if isinstance(row_list[row][col],str):
      print(type(row_list[row][col]))
      temp = re.findall(r'\d+', row_list[row][col])
      res = list(map(int, temp))
      len_res = len(res)
      if len_res >= 2:
        res = res[-1]+res[-2]
        copy_df.iloc[row,col] = res
      if len_res == 1:
         copy_df.iloc[row,col] = res
# Out:
# --------0---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------1---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------2---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------3---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------4---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------5---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------6---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------7---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------8---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------9---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------10---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------11---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------12---------
# <class 'str'>
# <class 'str'>
# --------13---------
# <class 'str'>
# <class 'str'>
# --------14---------
# <class 'str'>
# <class 'str'>
# --------15---------
# <class 'str'>
# <class 'str'>
# --------16---------
# <class 'str'>
# <class 'str'>
# --------17---------
# <class 'str'>
# <class 'str'>
# --------18---------
# <class 'str'>
# <class 'str'>
# --------19---------
# <class 'str'>
# <class 'str'>
# --------20---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------21---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------22---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------23---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------24---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------25---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------26---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------27---------
# <class 'str'>
# <class 'str'>
# <class 'str'>
# --------28---------
# <class 'str'>
# <class 'str'>
# --------29---------
# <class 'str'>
# --------30---------

# %%
word = "PRZESIADKi"
match = 'Przesiadki'
lista = []


for col in range(col_size):
  print(data_trasy.columns[col])
  for row in range(row_size):
    #print(type(row_list[row][col]))
    
    if isinstance(row_list[row][col],str):
     # print(type(row_list[row][col]))
      temp = re.findall(r'\d+', row_list[row][col])
      czy_przesiadka = re.findall(word,row_list[row][col],re.I) 
      res = list(map(int, temp))
      if len(res) != 3:
          if len(czy_przesiadka) == 1:
           # print(row_list[row][col])
            res.insert(0, 1)
          if len(czy_przesiadka) == 0:
           # print(row_list[row][col])
            res.insert(0, 0)
          if len(res) == 2:
            res.insert(2, 0)
      res.insert(3,data_trasy.columns[col])
      res.insert(4,data_trasy.index[row])
   

      
      lista.append(res)
# Out:
# Dworzec Główny
# Park Bieńkowicki
#  Park generała Mariana Langiewicza
# Park Mikołaja Kopernika
# Park Świętej Edyty Stein
# Park przy ul. Kolejowej
# Park Dąbski
# Park Jana Kasprowicza
# Park Stanisława Staszica
# Park Stabłowicki
# Park Tarnogajski
# (Obiekt zabytkowy) Park Juliusza Słowackiego
# Park Generała Władysława Andersa
# Park na Niskich Łąkach
# (Obiekt zabytkowy) Park Brochowski
# Park Marii Dąbrowskiej
# Park Stanisława Tołpy
# Park Kleciński
# Park Biskupiński
# Park Popowicki
# Park Pilczycki
# Park Strachowicki
# Park Złotnicki
# (Obiekt zabytkowy) Park Leśnicki
# (Obiekt zabytkowy) Park Południowy
# Park Skowroni
# Park Wschodni
# (Obiekt zabytkowy) Park Grabiszyński
# Park Zachodni
# (Obiekt zabytkowy) Park Szczytnicki
# Park Tysiąclecia

# %%
len(lista)
# Out:
# 297

# %%
dicts = []
for przesiadki, czas_jazdy, czas_pieszo, wyjazd_z,wyjazd_do in lista:
  object = {
      "liczba_przesiadek": przesiadki, 
      "czas_jazdy": czas_jazdy,
      "czas_pieszo": czas_pieszo,
      "wyjazd_z": wyjazd_z.strip(),
      "wyjazd_do": wyjazd_do.strip()
  }

  object2 = {
      "liczba_przesiadek": przesiadki, 
      "czas_jazdy": czas_jazdy,
      "czas_pieszo": czas_pieszo,
      "wyjazd_do": wyjazd_z.strip(),
      "wyjazd_z": wyjazd_do.strip()
  }
  dicts.append(object)
  dicts.append(object2)

# %%
len(dicts)
# Out:
# 594

# %%
dicts[dicts[0]["liczba_przesiadek"] == 1]
# Out:
# {'czas_jazdy': 26,
#  'czas_pieszo': 4,
#  'liczba_przesiadek': 1,
#  'wyjazd_do': 'Dworzec Główny',
#  'wyjazd_z': 'Park Bieńkowicki'}

# %%
bez_przesiadek = []

def znajdz_zero_przesiadek(d=dicts):
  for i in range(len(d)):
    if d[i]["liczba_przesiadek"] == 0:
      bez_przesiadek.append(d[i])



  return bez_przesiadek

# %%
trasy = znajdz_zero_przesiadek()

# %%
element_trasy = []

unique_park = list(set([t["wyjazd_z"] for t in trasy]))

# %%
wyznaczone_trasy = []
czy_stop = False
trasy_start = list(filter(lambda x: x["wyjazd_z"]=="Dworzec Główny",trasy))
for start in trasy_start:
  stop = start["wyjazd_do"]
  czas_podrozy = 30
  wyznaczone_trasy.append({
      "trasa": f"Dworzec Główny->{stop}",
      "długość": start["czas_jazdy"] + start["czas_pieszo"] + czas_podrozy,
      "ostatni_przystanek": stop
  })

while not czy_stop:
  czy_stop = True
  wyznaczone_trasy_tmp = wyznaczone_trasy.copy()
  wyznaczone_trasy = []
  print(f"Wyznaczono tras:{len(wyznaczone_trasy_tmp)}")
  for wyznaczone in wyznaczone_trasy_tmp:
    start = wyznaczone['ostatni_przystanek']
    przystanki = wyznaczone["trasa"].split("->")
    trasy_start = list(filter(lambda x: x["wyjazd_z"]==start,trasy))
    trasy_start = list(filter(lambda x: x["wyjazd_do"] not in przystanki,trasy_start))
    if len(trasy_start) > 0 and wyznaczone["długość"] < 600:
      czy_stop = False
    else:
      wyznaczone_trasy.append(wyznaczone)
      continue
    for start2 in trasy_start:
      stop = start2["wyjazd_do"]
      czas_podrozy = 30
      dlugosc = wyznaczone["długość"] + start2["czas_jazdy"] + start2["czas_pieszo"] + czas_podrozy
      wyznaczone_trasy.append({
          "trasa": wyznaczone["trasa"] + "->" + stop,
          "długość": dlugosc,
          "ostatni_przystanek": stop
      })
    wyznaczone_trasy = sorted(wyznaczone_trasy, key=lambda x: x["długość"])[:1000]
    
 # czy_stop = True
# Out:
# Wyznaczono tras:19
# Wyznaczono tras:168
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1000
# Wyznaczono tras:1005
# Wyznaczono tras:1005

# %%
wyznaczone = wyznaczone_trasy[0]

# %%
start = wyznaczone['ostatni_przystanek']
przystanki = wyznaczone["trasa"].split("->")
trasy_start = list(filter(lambda x: x["wyjazd_do"]==start,dicts))

# %%
trasy_start
# Out:
# [{'czas_jazdy': 25,
#   'czas_pieszo': 5,
#   'liczba_przesiadek': 0,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Dworzec Główny'},
#  {'czas_jazdy': 17,
#   'czas_pieszo': 9,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park Bieńkowicki'},
#  {'czas_jazdy': 36,
#   'czas_pieszo': 7,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park generała Mariana Langiewicza'},
#  {'czas_jazdy': 7,
#   'czas_pieszo': 4,
#   'liczba_przesiadek': 0,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park Mikołaja Kopernika'},
#  {'czas_jazdy': 38,
#   'czas_pieszo': 9,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park Świętej Edyty Stein'},
#  {'czas_jazdy': 24,
#   'czas_pieszo': 9,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park przy ul. Kolejowej'},
#  {'czas_jazdy': 42,
#   'czas_pieszo': 9,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park Dąbski'},
#  {'czas_jazdy': 25,
#   'czas_pieszo': 5,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': '(Obiekt zabytkowy) Park Juliusza Słowackiego'},
#  {'czas_jazdy': 45,
#   'czas_pieszo': 16,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park Pilczycki'},
#  {'czas_jazdy': 45,
#   'czas_pieszo': 29,
#   'liczba_przesiadek': 1,
#   'wyjazd_do': '(Obiekt zabytkowy) Park Brochowski',
#   'wyjazd_z': 'Park Tysiąclecia'}]
